# %% [markdown]
# # Tarea 4
#
# ## Procedimientos
# **Importar librerias**

# %%
from skimage import io
import pandas as pd

# %% [markdown]
# **Leer una imagen y mostrarla:**

# %%
img = io.imread("enviorment.jpg")
io.imshow(img)
img.shape
# Out:
# C:\Users\alang\AppData\Local\Temp\ipykernel_9680\4102251232.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img)
# (414, 735, 3)

# %% [markdown]
# **Aplanar imagen:**

# %%
df = pd.DataFrame(img.flatten())
filepath = "pixel_values.xlsx"
df.to_excel(filepath, index=False)

# %% [markdown]
# **Formagto RGB:**

# %%
from skimage import color
import cv2

img = io.imread("enviorment.jpg")
img_bw = cv2.imread("enviorment.jpg", 0)
print(img_bw)
io.imshow(img_bw)
# Out:
# [[38 41 43 ... 31 32 35]
#  [37 41 45 ... 27 28 30]
#  [39 44 45 ... 27 28 30]
#  ...
#  [35 29 23 ... 26 27 30]
#  [36 31 24 ... 27 27 29]
#  [38 34 28 ... 30 30 31]]
# C:\Users\alang\AppData\Local\Temp\ipykernel_9680\616054745.py:7: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_bw)
